# %%
a = [1,5,7,3,4,8,9,3,1,8,6,10,3,6,11,17]

for i in range(len(a)):
    for j in range (i, len(a)):
        if a[i] > a[j]:
            a[i], a[j] = a[j], a[i]
print(a)
# Out:
# [1, 1, 3, 3, 3, 4, 5, 6, 6, 7, 8, 8, 9, 10, 11, 17]

# %%
products = [{"name": "Milk", "price": 1.50}, {"name": "Cheese", "price": 3.20}]
sorted(products, key=lambda x: x["price"])
# Out:
# [{'name': 'Milk', 'price': 1.5}, {'name': 'Cheese', 'price': 3.2}]

# %%
markup = lambda cost, pct: cost * (1 + pct)
markup(10, 0.3)
# Out:
# 13.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
import os
import re
import math
import random
import datetime
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
path = "/Users/gokulsathyan/Desktop/Bank fraud detection/data/"

class Data_Ingestion:

    def __init__(self, path):

        try:
            self.path = path
            self.data = pd.read_csv(path)
        except Exception as e:
            print(f"Error loading data: {e}")

# %%
os.path.dirname(__file__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 os.path.dirname(__file__)
#
# NameError: name '__file__' is not defined
